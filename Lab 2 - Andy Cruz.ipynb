# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-56b114c3-6156-4da7-8d1c-e8c9fd6b17a1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-56b114c3-6156-4da7-8d1c-e8c9fd6b17a1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
data_1 = pd.read_csv("/content/ROD_PIEZO_1.csv", usecols=[3,4,9,10], names=['time_A', 'volt_A','time_B','volt_B'])
data_2 = pd.read_csv("/content/ROD_PIEZO_2.csv", usecols=[3,4,9,10], names=['time_A', 'volt_A','time_B','volt_B'])
data_3 = pd.read_csv("/content/ROD_PIEZO_3.csv", usecols=[3,4,9,10], names=['time_A', 'volt_A','time_B','volt_B'])
data_4 = pd.read_csv("/content/ROD_PIEZO_4.csv", usecols=[3,4,9,10], names=['time_A', 'volt_A','time_B','volt_B'])
data_5 = pd.read_csv("/content/ROD_PIEZO_5.csv", usecols=[3,4,9,10], names=['time_A', 'volt_A','time_B','volt_B'])

print(data_1)
# Out:
#         time_A  volt_A    time_B  volt_B
# 0    -0.000880    0.00 -0.000880     0.0
# 1    -0.000879    0.02 -0.000879     0.0
# 2    -0.000878    0.02 -0.000878     0.0
# 3    -0.000877    0.00 -0.000877     0.0
# 4    -0.000876    0.02 -0.000876     0.0
# ...        ...     ...       ...     ...
# 2495  0.001615    3.46  0.001615     0.0
# 2496  0.001616    3.46  0.001616     0.0
# 2497  0.001617    3.46  0.001617     0.0
# 2498  0.001618    3.46  0.001618     0.0
# 2499  0.001619    3.46  0.001619     0.0
#
# [2500 rows x 4 columns]

# %%
import matplotlib.pyplot as plt
#plt.scatter([data_1.time_A,data_1.time_B],[data_1.volt_A,data_1.volt_B])
plt.scatter(data_1.time_A,data_1.volt_A)
plt.scatter(data_1.time_B,data_1.volt_B)
plt.show()
