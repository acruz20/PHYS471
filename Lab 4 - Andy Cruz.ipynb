# %%
# !wget -q https://drive.google.com/drive/folders/1tcu2djy0KofpIIbxTExq58ZC9ltZ4l25?usp=share_link

# %%
import pandas as pd
data_1 = pd.read_csv("/content/LASER_MEASURE.csv",  names=['aperture', 'volt_1','volt_2','volt_3','volt_4','volt_5'])

print(data_1)
# Out:
#    aperture  volt_1  volt_2  volt_3  volt_4  volt_5
# 0      2.00  0.7858     NaN  0.5245  0.5300  0.1166
# 1      1.00  0.6505     NaN  0.3336  0.3168  0.0399
# 2      0.75  0.6496  1.0922  0.2455  0.2167  0.0270
# 3      0.50  0.5972  1.0922  0.0544  0.0957  0.0101

# %% [markdown]
# Cyclic RMS Voltage(V) for each run
# 1-2.03
# 2-3.95
# 3-1.78
# 4-1.78
# 5-1.57
