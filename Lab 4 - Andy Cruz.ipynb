# %% [markdown]
# <a href="https://colab.research.google.com/github/acruz20/PHYS471/blob/main/Lab%204%20-%20Andy%20Cruz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 # !git clone https://github.com/acruz20/PHYS471
# Out:
# Cloning into 'PHYS471'...
# remote: Enumerating objects: 19, done.
# remote: Counting objects: 100% (19/19), done.
# remote: Compressing objects: 100% (19/19), done.
# remote: Total 19 (delta 5), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (19/19), 425.66 KiB | 2.63 MiB/s, done.

# %% [markdown]
# Cyclic RMS Voltage(V) for each run
# 1-2.03
# 2-3.95
# 3-1.78
# 4-1.78
# 5-1.57

# %%
import pandas as pd
data_1 = pd.read_csv("/content/PHYS471/LASER_MEASURE.csv",  names=['aperture_r', 'volt_1','volt_2','volt_3','volt_4','volt_5'])

# %% [markdown]
# Intensity vs Aperture Radius

# %%
import matplotlib.pyplot as plt
plt.scatter(data_1.aperture_r,data_1.volt_1)
plt.scatter(data_1.aperture_r,data_1.volt_3)
plt.scatter(data_1.aperture_r,data_1.volt_4)
plt.scatter(data_1.aperture_r,data_1.volt_5)
plt.xlabel('Aperture Radius (mm)')
plt.ylabel('Voltage Squared (V^2)')
plt.title('Impact Times for Hammer and Piezo Run 1')
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# Intensity vs Aperture Area

# %%
import numpy as np
aperture_A = np.pi*data_1.aperture_r**2
#plt.scatter(aperture_A,data_1.volt_1**2,label = 'Cyclic RMS 2.03 V')
plt.scatter(aperture_A,data_1.volt_3**2,label = 'Cyclic RMS 1.78 V Run 1')
plt.scatter(aperture_A,data_1.volt_4**2,label = 'Cyclic RMS 1.78 V Run 2')
plt.scatter(aperture_A,data_1.volt_5**2,label = 'Cyclic RMS 1.57 V')
plt.xlabel('Aperture Area (mm^2)')
plt.ylabel('Voltage Squared (V^2)')
plt.title('Sensor Voltage Against Aperture Area')
plt.legend()
plt.show()
