# %% [markdown]
# <a href="https://colab.research.google.com/github/acruz20/PHYS471/blob/main/Lab%201%20-%20Andy%20Cruz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 # !git clone https://github.com/acruz20/PHYS471
# Out:
# Cloning into 'PHYS471'...
# remote: Enumerating objects: 13, done.
# remote: Counting objects: 100% (13/13), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 13 (delta 3), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (13/13), 161.94 KiB | 2.79 MiB/s, done.

# %%
import pandas as pd
data_1 = pd.read_csv("/content/PHYS471/TEK0000.CSV", usecols=[3,4], names=['freq', 'level'])
data_2 = pd.read_csv("/content/PHYS471/TEK0001.CSV", usecols=[3,4], names=['freq', 'level'])

# %%
import matplotlib.pyplot as plt
plt.scatter(data_1.freq,data_1.level)
plt.xlabel('Frequency (Hz)')
plt.ylabel('Level (dB)')
plt.title('FFT Spectrum of Tuning Fork A')
plt.show()

# %%
plt.scatter(data_2.freq,data_2.level)
plt.xlabel('Frequency (Hz)')
plt.ylabel('Level (dB)')
plt.title('FFT Spectrum of Tuning Fork B')
plt.show()
